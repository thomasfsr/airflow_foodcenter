# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os 

folder_data = '../data'

files = os.listdir(folder_data)

df_cha = pd.read_csv(f'{folder_data}/{files[0]}',encoding='ISO-8859-1')
print(files[0])
df_del = pd.read_csv(f'{folder_data}/{files[1]}',encoding='ISO-8859-1')
print(files[1])
df_dri = pd.read_csv(f'{folder_data}/{files[2]}',encoding='ISO-8859-1')
print(files[2])
df_hub = pd.read_csv(f'{folder_data}/{files[3]}',encoding='ISO-8859-1')
print(files[3])
df_ord = pd.read_csv(f'{folder_data}/{files[4]}',encoding='ISO-8859-1')
print(files[4])
df_pay = pd.read_csv(f'{folder_data}/{files[5]}',encoding='ISO-8859-1')
print(files[5])
df_sto = pd.read_csv(f'{folder_data}/{files[6]}',encoding='ISO-8859-1')
print(files[6])
# Out:
# channels.csv
# deliveries.csv
# drivers.csv
# hubs.csv
# orders.csv
# payments.csv
# stores.csv

# %% [markdown]
# - Numa ação de marketing, para atrair mais entregadores, vamos dar uma bonificação
# para os 20 entregadores que possuem maior distância percorrida ao todo. A bonificação vai variar
# de acordo com o tipo de profissional que ele é e o modelo que ele usa para se locomover (moto, bike, etc).
#  Levante essas informações.

# %% [markdown]
# quantas modalidades existem:

# %%
df_dri.driver_modal.unique()
# Out:
# array(['MOTOBOY', 'BIKER'], dtype=object)

# %%
df_dri.driver_modal.value_counts()
# Out:
# driver_modal
# MOTOBOY    3222
# BIKER      1602
# Name: count, dtype: int64

# %%
df_dri.driver_type.unique()
# Out:
# array(['LOGISTIC OPERATOR', 'FREELANCE'], dtype=object)

# %%
df_dri.driver_type.value_counts()
# Out:
# driver_type
# FREELANCE            3939
# LOGISTIC OPERATOR     885
# Name: count, dtype: int64

# %%
df_del.delivery_status.value_counts()
# Out:
# delivery_status
# DELIVERED     371367
# CANCELLED       7253
# DELIVERING       223
# Name: count, dtype: int64

# %%
#transformation
df_delivered = df_del[df_del['delivery_status'] == 'DELIVERED']
df_delivered_nona = df_delivered.dropna()
df_delivered_only_null = df_delivered[df_delivered['driver_id'].isna()]

# %%
df_delivered.loc[:,'isnull_or_notnull'] = df_delivered['driver_id'].map(lambda x: 'isnull' if pd.isnull(x) else 'notnull')
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_16224\2812216114.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_delivered.loc[:,'isnull_or_notnull'] = df_delivered['driver_id'].map(lambda x: 'isnull' if pd.isnull(x) else 'notnull')

# %%
df_delivered.isnull_or_notnull.value_counts()
# Out:
# isnull_or_notnull
# notnull    362766
# isnull       8601
# Name: count, dtype: int64

# %%
sns.histplot(df_delivered,x='delivery_distance_meters', hue='isnull_or_notnull',bins=10)
plt.ylim(0,20000)
plt.show()

# %%
sns.histplot(df_delivered_only_null,x='delivery_distance_meters',bins=10)
plt.ylim(0,1000)
plt.show()

# %%
sns.histplot(df_delivered_nona,x='delivery_distance_meters',bins=10)
plt.ylim(0,200)
plt.show()

# %%
sns.boxplot(df_delivered, hue='isnull_or_notnull', y='delivery_distance_meters')
plt.ylim(0,20000)
plt.show()

# %%
Q1 = df_delivered['delivery_distance_meters'].quantile(0.25)
Q3 = df_delivered['delivery_distance_meters'].quantile(0.75)

#Q1isna = df_delivered_isna['delivery_distance_meters'].quantile(0.25)
#Q3isna = df_delivered_isna['delivery_distance_meters'].quantile(0.75)

#Q1nona = df_delivered_nona['delivery_distance_meters'].quantile(0.25)
#Q3nona = df_delivered_nona['delivery_distance_meters'].quantile(0.75)

IQR = Q3 - Q1
#IQRisna = Q3isna - Q1isna
#IQRnona = Q3nona - Q1nona

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df_no_outliers = df_delivered[(df_delivered['delivery_distance_meters'] <= upper_bound)]

#lower_bound = Q1isna - 1.5 * IQRisna
#upper_bound = Q3isna + 1.5 * IQRisna
#df_no_outliers_isna = df_delivered_isna[(df_delivered_isna['delivery_distance_meters'] <= upper_bound)]
#
#lower_bound = Q1nona - 1.5 * IQRnona
#upper_bound = Q3nona + 1.5 * IQRnona
#df_no_outliers_nona = df_delivered_nona[(df_delivered_nona['delivery_distance_meters'] <= upper_bound)]

# %%
sns.boxplot(df_no_outliers, hue='isnull_or_notnull', y='delivery_distance_meters')
# Out:
# <Axes: ylabel='delivery_distance_meters'>

# %%
sns.histplot(df_no_outliers,x='delivery_distance_meters',bins=40,kde=True, hue='isnull_or_notnull')
# Out:
# <Axes: xlabel='delivery_distance_meters', ylabel='Count'>

# %%
sns.histplot(df_no_outliers[df_no_outliers['isnull_or_notnull']=='isnull'],x='delivery_distance_meters',bins=40)
# Out:
# <Axes: xlabel='delivery_distance_meters', ylabel='Count'>

# %%
sns.histplot(df_no_outliers[df_no_outliers['isnull_or_notnull']=='notnull'],x='delivery_distance_meters',bins=40)
# Out:
# <Axes: xlabel='delivery_distance_meters', ylabel='Count'>

# %%
df_ord[:1]
# Out:
#    order_id  store_id  channel_id  payment_order_id  delivery_order_id  \
# 0  68405119      3512           5          68405119           68405119
#
#   order_status  order_amount  order_delivery_fee  order_delivery_cost  \
# 0     CANCELED          62.7                 0.0                  NaN
#
#    order_created_hour  ...  order_moment_delivering  order_moment_delivered  \
# 0                   0  ...                      NaN                     NaN
#
#    order_moment_finished  order_metric_collected_time  \
# 0                    NaN                          NaN
#
#   order_metric_paused_time order_metric_production_time  \
# 0                      NaN                          NaN
#
#   order_metric_walking_time order_metric_expediton_speed_time  \
# 0                       NaN                               NaN
#
#   order_metric_transit_time order_metric_cycle_time
# 0                       NaN                     NaN
#
# [1 rows x 29 columns]

# %%
df_sto[:1]
# Out:
#    store_id  hub_id store_name store_segment  store_plan_price  \
# 0         3       2    CUMIURI          FOOD               0.0
#
#    store_latitude  store_longitude
# 0             NaN              NaN

# %%
df_hub
# Out:
#     hub_id          hub_name        hub_city hub_state  hub_latitude  \
# 0        2     BLUE SHOPPING    PORTO ALEGRE        RS    -30.047415
# 1        3    GREEN SHOPPING    PORTO ALEGRE        RS    -30.037415
# 2        4      RED SHOPPING    PORTO ALEGRE        RS    -30.021948
# 3        5     FUNK SHOPPING  RIO DE JANEIRO        RJ    -23.000750
# 4        8   GOLDEN SHOPPING  RIO DE JANEIRO        RJ    -22.921475
# 5       13  HIP HOP SHOPPING  RIO DE JANEIRO        RJ    -22.885820
# 6       16   PEOPLE SHOPPING  RIO DE JANEIRO        RJ    -23.017472
# 7       17    SMALL SHOPPING       SÃO PAULO        SP    -23.592004
# 8       18     STAR SHOPPING  RIO DE JANEIRO        RJ    -22.945495
# 9       20   PURPLE SHOPPING  RIO DE JANEIRO        RJ    -22.996848
# 10      21     WOLF SHOPPING       SÃO PAULO        SP    -23.550407
# 11      22    COLOR SHOPPING  RIO DE JANEIRO        RJ    -23.000753
# 12      25   AVENUE SHOPPING       SÃO PAULO        SP    -23.567703
# 13      26      SQL SHOPPING       SÃO PAULO        SP    -23.563019
# 14      27    SAMPA SHOPPING       SÃO PAULO        SP    -23.622995
# 15      28      RAP SHOPPING       SÃO PAULO        SP    -23.595001
# 16      29   SUBWAY SHOPPING       SÃO PAULO        SP    -23.561053
# 17      31   PAGODE SHOPPING       SÃO PAULO        SP    -23.629826
# 18      33   COFFEE SHOPPING       SÃO PAULO        SP    -23.579067
# 19      35    BEACH SHOPPING  RIO DE JANEIRO        RJ    -22.969880
# 20      36    BLACK SHOPPING    PORTO ALEGRE        RS    -30.085743
# 21      37    RIVER SHOPPING       SÃO PAULO        SP    -23.507105
# 22      42      PHP SHOPPING        CURITIBA        PR    -25.438105
# 23      43  HOTMILK SHOPPING        CURITIBA        PR    -25.441221
# 24      44  FORTRAN SHOPPING        CURITIBA        PR    -25.435140
# 25      51     RUBY SHOPPING  RIO DE JANEIRO        RJ    -22.923675
# 26      55   ELIXIR SHOPPING       SÃO PAULO        SP    -23.521776
# 27      73  HUBLESS SHOPPING       SÃO PAULO        SP    -22.947461
# 28      75   PYTHON SHOPPING        CURITIBA        PR    -25.477073
# 29      85    REACT SHOPPING       SÃO PAULO        SP    -23.513353
# 30      86        R SHOPPING       SÃO PAULO        SP    -23.541502
# 31      91    GAROA SHOPPING       SÃO PAULO        SP    -23.525124
#
#     hub_longitude
# 0      -51.213510
# 1      -51.203520
# 2      -51.208382
# 3      -43.318282
# 4      -43.234774
# 5      -43.279218
# 6      -43.479939
# 7      -46.636504
# 8      -43.182181
# 9      -43.359636
# 10     -46.697316
# 11     -43.383771
# 12     -46.642043
# 13     -46.652621
# 14     -46.699204
# 15     -46.685984
# 16     -46.558976
# 17     -46.735203
# 18     -46.592820
# 19     -43.370811
# 20     -51.245997
# 21     -46.718197
# 22     -49.266532
# 23     -49.277690
# 24     -49.316788
# 25     -43.567757
# 26     -46.624152
# 27     -43.183467
# 28     -49.289660
# 29     -46.618353
# 30     -46.576618
# 31     -46.546807

# %% [markdown]
# Como podemos notar grande parte das possíveis fraudes estão em usuários nulos. Para esta tarefa é recomendado remover usuarios nulos, pois sem identicação é impossivel contacta-los para anunciar que ganharam.

# %%
sns.histplot(df_ord, x='order_amount', bins=4)
plt.ylim(0,10)
plt.show()

# %%
#Transformation
df_merged = df_no_outliers[df_no_outliers['isnull_or_notnull']=='notnull'].merge(df_dri[['driver_modal', 'driver_type','driver_id']],on='driver_id', how='left').drop('isnull_or_notnull',axis=1)

# %%
sns.histplot(df_merged,x='delivery_distance_meters',bins=40, kde=True, hue= 'driver_modal')
# Out:
# <Axes: xlabel='delivery_distance_meters', ylabel='Count'>

# %%
sns.histplot(df_merged,x='delivery_distance_meters',bins=40, kde=True, hue= 'driver_type')
# Out:
# <Axes: xlabel='delivery_distance_meters', ylabel='Count'>

# %%
sns.boxplot(df_merged, y='delivery_distance_meters' ,hue = 'driver_modal')
# Out:
# <Axes: ylabel='delivery_distance_meters'>

# %%
sns.boxplot(df_merged, y='delivery_distance_meters' ,hue = 'driver_type')
# Out:
# <Axes: ylabel='delivery_distance_meters'>

# %%
df_merged.driver_modal.value_counts(normalize=True)
# Out:
# driver_modal
# MOTOBOY    0.719543
# BIKER      0.280457
# Name: proportion, dtype: float64

# %%
df_merged.driver_type.value_counts(normalize=True)
# Out:
# driver_type
# FREELANCE            0.728462
# LOGISTIC OPERATOR    0.271538
# Name: proportion, dtype: float64

# %%
top_no_strat = df_merged[['driver_id','delivery_distance_meters']]\
    .groupby('driver_id').sum()\
        .sort_values('delivery_distance_meters',ascending=False)\
            .merge(df_dri[['driver_modal', 'driver_type','driver_id']],on='driver_id', how='left').reset_index(drop=True)

# %%
top_no_strat
# Out:
#       driver_id  delivery_distance_meters driver_modal        driver_type
# 0       25651.0                31374905.0      MOTOBOY  LOGISTIC OPERATOR
# 1       26223.0                19022256.0      MOTOBOY  LOGISTIC OPERATOR
# 2        7615.0                 2762581.0      MOTOBOY  LOGISTIC OPERATOR
# 3       17749.0                 2416127.0      MOTOBOY          FREELANCE
# 4        9806.0                 2403981.0      MOTOBOY  LOGISTIC OPERATOR
# ...         ...                       ...          ...                ...
# 4522    42665.0                     244.0        BIKER          FREELANCE
# 4523     5110.0                     171.0      MOTOBOY          FREELANCE
# 4524    32545.0                     148.0        BIKER          FREELANCE
# 4525    40411.0                      69.0        BIKER          FREELANCE
# 4526    53115.0                      34.0        BIKER          FREELANCE
#
# [4527 rows x 4 columns]

# %%
prop= top_no_strat[['driver_modal','driver_type']].value_counts(normalize=True).values

# %%
top_no_strat[['driver_modal','driver_type']].value_counts(normalize=True)
# Out:
# driver_modal  driver_type
# MOTOBOY       FREELANCE            0.463883
# BIKER         FREELANCE            0.349459
# MOTOBOY       LOGISTIC OPERATOR    0.186437
# BIKER         LOGISTIC OPERATOR    0.000221
# Name: proportion, dtype: float64

# %%
st1 =int(prop[0]*20)
st2 =int(prop[1]*20)
st3 =int(prop[2]*20)
st4 =20-(st1+st2+st3)

# %%
print(st1, st2, st3, st4)
# Out:
# 9 6 3 2

# %%
st1 =int(prop[0]*20)
st2 =int(prop[1]*20)
st3 =int(prop[2]*20)
st4 =20-(st1+st2+st3)
df_strat= pd.concat([top_no_strat[(top_no_strat['driver_modal']=='MOTOBOY') & (top_no_strat['driver_type']=='FREELANCE')][:st1],
        top_no_strat[(top_no_strat['driver_modal']=='BIKER') & (top_no_strat['driver_type']=='FREELANCE')][:st2],
        top_no_strat[(top_no_strat['driver_modal']=='MOTOBOY') & (top_no_strat['driver_type']=='LOGISTIC OPERATOR')][:st3],
        top_no_strat[(top_no_strat['driver_modal']=='BIKER') & (top_no_strat['driver_type']=='LOGISTIC OPERATOR')][:st4]
],axis=0).sort_index()

# %%
if len(df_strat)!=20:
    df_strat= pd.concat([top_no_strat[(top_no_strat['driver_modal']=='MOTOBOY') & (top_no_strat['driver_type']=='FREELANCE')][:st1+1],
        top_no_strat[(top_no_strat['driver_modal']=='BIKER') & (top_no_strat['driver_type']=='FREELANCE')][:st2],
        top_no_strat[(top_no_strat['driver_modal']=='MOTOBOY') & (top_no_strat['driver_type']=='LOGISTIC OPERATOR')][:st3],
        top_no_strat[(top_no_strat['driver_modal']=='BIKER') & (top_no_strat['driver_type']=='LOGISTIC OPERATOR')][:st4]
],axis=0).sort_index()

# %%
df_strat['driver_id']= df_strat['driver_id'].astype('int64')

# %%
df_strat
# Out:
#       driver_id  delivery_distance_meters driver_modal        driver_type
# 0         25651                31374905.0      MOTOBOY  LOGISTIC OPERATOR
# 1         26223                19022256.0      MOTOBOY  LOGISTIC OPERATOR
# 2          7615                 2762581.0      MOTOBOY  LOGISTIC OPERATOR
# 3         17749                 2416127.0      MOTOBOY          FREELANCE
# 6          7799                 2393980.0      MOTOBOY          FREELANCE
# 8         15561                 2330998.0      MOTOBOY          FREELANCE
# 10         5527                 2235934.0      MOTOBOY          FREELANCE
# 11        11063                 2214371.0      MOTOBOY          FREELANCE
# 14        26536                 2097124.0      MOTOBOY          FREELANCE
# 18        17457                 1996217.0      MOTOBOY          FREELANCE
# 21         7033                 1941427.0      MOTOBOY          FREELANCE
# 23        24584                 1875965.0      MOTOBOY          FREELANCE
# 29         7480                 1791147.0      MOTOBOY          FREELANCE
# 218        3780                  867126.0        BIKER          FREELANCE
# 233         794                  841202.0        BIKER          FREELANCE
# 260       12724                  733939.0        BIKER          FREELANCE
# 267        7638                  719445.0        BIKER          FREELANCE
# 321       18487                  623923.0        BIKER          FREELANCE
# 322        7773                  621958.0        BIKER          FREELANCE
# 2432      32843                   32572.0        BIKER  LOGISTIC OPERATOR

# %% [markdown]
# - Além disso, o time de Pricing precisa ajustar os valores pagos aos entregadores. Para isso, eles precisam da distribuição da distância média percorrida pelos motoqueiros separada por estado, já que cada região terá seu preço.

# %%
df_merged_store_id = df_merged.merge(df_ord[['store_id','order_id']],how='left', left_on='delivery_order_id', right_on='order_id')

# %%
df_merged_store_id = df_merged_store_id.drop('delivery_order_id', axis=1)

# %%
df_state= df_merged_store_id.merge(df_sto[['hub_id','store_id']], on='store_id', how='left')\
    .merge(df_hub[['hub_id','hub_state']],on='hub_id', how='left')

# %%
df_state
# Out:
#         delivery_id  driver_id  delivery_distance_meters delivery_status  \
# 0           2174658     8378.0                    5199.0       DELIVERED
# 1           2174660     2473.0                     410.0       DELIVERED
# 2           2174661     7615.0                    3784.0       DELIVERED
# 3           2174663     8378.0                    5714.0       DELIVERED
# 4           2174675    10463.0                    3746.0       DELIVERED
# ...             ...        ...                       ...             ...
# 347435      3128338    24358.0                    3667.0       DELIVERED
# 347436      3130930    22345.0                    3414.0       DELIVERED
# 347437      3135849    55429.0                    2546.0       DELIVERED
# 347438      3142829    47016.0                    3106.0       DELIVERED
# 347439      3144739    10504.0                    2919.0       DELIVERED
#
#        driver_modal        driver_type  store_id  order_id  hub_id hub_state
# 0           MOTOBOY          FREELANCE       631  68413340      28        SP
# 1             BIKER          FREELANCE       236  68414309      13        RJ
# 2           MOTOBOY  LOGISTIC OPERATOR      1016  68416230      36        RS
# 3           MOTOBOY          FREELANCE       631  68412721      28        SP
# 4           MOTOBOY  LOGISTIC OPERATOR      3265  68414018      37        SP
# ...             ...                ...       ...       ...     ...       ...
# 347435      MOTOBOY          FREELANCE       983  93125719      35        RJ
# 347436      MOTOBOY          FREELANCE       100  93111400       8        RJ
# 347437      MOTOBOY          FREELANCE       435  82340127      16        RJ
# 347438      MOTOBOY          FREELANCE      2112  88586792      51        RJ
# 347439      MOTOBOY          FREELANCE        53  93026454       8        RJ
#
# [347440 rows x 10 columns]

# %%
df_state[['hub_state','delivery_distance_meters']].groupby('hub_state').mean()
# Out:
#            delivery_distance_meters
# hub_state
# PR                      2659.183604
# RJ                      2066.090581
# RS                      2877.703782
# SP                      2279.125666

# %%
df_ord.order_status.unique()
# Out:
# array(['CANCELED', 'FINISHED'], dtype=object)

# %%
df_ord[df_ord['order_status']=='FINISHED']
# Out:
#         order_id  store_id  channel_id  payment_order_id  delivery_order_id  \
# 8       68410055      2181          35          68410055           68410055
# 17      68412721       631           5          68412721           68412721
# 18      68413340       631           5          68413340           68413340
# 19      68414018      3265           5          68414018           68414018
# 20      68414309       236           5          68414309           68414309
# ...          ...       ...         ...               ...                ...
# 368994  93139806      2074           5          93139806           93139806
# 368995  93139809       707           5          93139809           93139809
# 368996  93139813       631           5          93139813           93139813
# 368997  93139814       631           5          93139814           93139814
# 368998  93139817       236           5          93139817           93139817
#
#        order_status  order_amount  order_delivery_fee  order_delivery_cost  \
# 8          FINISHED        394.80                0.01                 6.00
# 17         FINISHED        195.05               11.90                10.93
# 18         FINISHED         46.90               11.90                11.36
# 19         FINISHED         45.80                0.00                10.28
# 20         FINISHED         94.90               11.90                 6.00
# ...             ...           ...                 ...                  ...
# 368994     FINISHED         28.00                0.00                 0.00
# 368995     FINISHED         49.00               11.90                10.04
# 368996     FINISHED        128.70               11.90                 9.29
# 368997     FINISHED        127.40               11.90                 5.00
# 368998     FINISHED        104.70               11.90                10.67
#
#         order_created_hour  ...  order_moment_delivering  \
# 8                        2  ...      1/2/2021 6:35:49 PM
# 17                      14  ...      1/1/2021 2:49:18 PM
# 18                      14  ...      1/1/2021 2:42:08 PM
# 19                      14  ...      1/1/2021 2:58:17 PM
# 20                      14  ...      1/1/2021 2:43:36 PM
# ...                    ...  ...                      ...
# 368994                  23  ...     5/1/2021 12:44:39 AM
# 368995                  23  ...     5/1/2021 12:36:36 AM
# 368996                  23  ...     5/1/2021 12:47:47 AM
# 368997                  23  ...     5/1/2021 12:31:50 AM
# 368998                  23  ...     5/1/2021 12:26:24 AM
#
#         order_moment_delivered  order_moment_finished  \
# 8                          NaN    1/2/2021 6:57:34 PM
# 17                         NaN    1/1/2021 4:12:36 PM
# 18                         NaN    1/1/2021 3:31:54 PM
# 19                         NaN    1/1/2021 3:09:20 PM
# 20                         NaN    1/1/2021 2:50:20 PM
# ...                        ...                    ...
# 368994                     NaN    5/1/2021 1:08:04 AM
# 368995                     NaN   5/1/2021 12:57:16 AM
# 368996                     NaN    5/1/2021 1:05:20 AM
# 368997                     NaN   5/1/2021 12:45:00 AM
# 368998                     NaN   5/1/2021 12:47:31 AM
#
#         order_metric_collected_time order_metric_paused_time  \
# 8                              6.63                     4.55
# 17                             0.27                    10.22
# 18                             7.03                     3.10
# 19                            10.22                     3.03
# 20                             2.37                     1.45
# ...                             ...                      ...
# 368994                         0.67                    18.33
# 368995                         1.42                     3.48
# 368996                        11.72                     6.38
# 368997                          NaN                      NaN
# 368998                          NaN                      NaN
#
#        order_metric_production_time order_metric_walking_time  \
# 8                           2391.25                      7.17
# 17                            26.07                      0.83
# 18                            14.62                      9.57
# 19                            27.48                     10.25
# 20                            15.78                      5.33
# ...                             ...                       ...
# 368994                        22.00                      4.80
# 368995                        27.32                      6.13
# 368996                        29.97                     11.75
# 368997                        30.27                       NaN
# 368998                        16.33                       NaN
#
#        order_metric_expediton_speed_time order_metric_transit_time  \
# 8                                  11.72                     21.75
# 17                                 11.05                     83.30
# 18                                 12.67                     49.78
# 19                                 13.28                     11.05
# 20                                  6.78                      6.73
# ...                                  ...                       ...
# 368994                             23.13                     23.42
# 368995                              9.62                     20.67
# 368996                             18.13                     17.55
# 368997                              1.88                     13.17
# 368998                             10.27                     21.12
#
#        order_metric_cycle_time
# 8                      2424.72
# 17                      120.42
# 18                       77.05
# 19                       51.82
# 20                       29.30
# ...                        ...
# 368994                   68.53
# 368995                   57.60
# 368996                   65.65
# 368997                   45.32
# 368998                   47.72
#
# [352020 rows x 29 columns]
